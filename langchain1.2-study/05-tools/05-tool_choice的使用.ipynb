# %% [markdown]
# # tool_choice的使用
#
# ## 1、tool_choice的取值为none

# %%
import os
from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = llm_deepseek.bind_tools([get_weather],tool_choice="none")

response = model_with_tools.invoke("北京今天的天气如何？")
rprint(response)
# Out:
# AIMessage(
#     content='抱歉，我无法获取实时天气数据，所以不能准确告诉你北京今天（2026-05-07）的天气情况。\n\n建议你通过以下方
# 式查看：\n- 手机自带天气 App，搜索“北京”\n- 中国天气网（weather.com.cn）\n- 北京市气象局官方微博/网站\n-
# 墨迹天气、彩云天气等 App\n\n如果你把当前温度、天气状况发给我，我可以帮你判断穿衣、出行是否需要带伞等。',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content': '我们需要回答用户问北京今天天气。需要实时信息。当前日期
# 2026-05-07，但系统知识截止2024-06。需要查天气？作为API没有直接工具。我们不能获取实时天气。需要说明无法实时查询，可
# 建议查天气应用，或者如果知道？不应该编造。可以回答：我无法获取实时天气，建议查看中国天气网/墨迹/手机天气。也许可以
# 给一般性5月北京气候？用户问“今天”的天气。需要准确。我们没有实时数据。应该直接说明无法实时获取，并建议如何查。可能可
# 以用“如果你告诉我具体日期/城市，我无法联网”但日期已知
# 2026-05-07。不要编造。可以请求用户提供天气数据？或者给查询方法。最终回答要简洁有帮助。\n\n但是注意，系统当前日期
# 2026-05-07。用户问北京今天。我们无法访问互联网，不能提供实时天气。可以回答：抱歉，我无法获取实时天气数据；建议打开
# 天气App或访问中国天气网查询“北京”。如果你需要，我可以根据季节给穿衣建议？但可能不需要。\n\n需要遵守政策？无。\n\n可
# 以尝试提供北京5月7日气候统计？但“今天”具体天气未知。可以说：北京5月上旬通常白天20–27°C，夜间10–15°C，干燥多风，早晚
# 温差大。但这不是今天实际天气。最好先声明不能实时查询，不要误导。\n\n最终格式：抱歉，我无法联网获取实时天气。建议：
# 手机天气App、中国天气网、北京市气象局微博/网站。如果要我帮你判断穿衣，可以告诉我当前温度/天气状况。或者我可以给一般
# 性建议。这样回答满足。\n\n但也许用户期望 ChatGPT
# ...

# %% [markdown]
# ## 2、tool_choice的取值为auto

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = llm_deepseek.bind_tools([get_weather],tool_choice="auto")

# response = model_with_tools.invoke("北京今天的天气如何？")
response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='2 + 3 = 5',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 11,
#             'prompt_tokens': 134,
#             'total_tokens': 145,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 3,
#                 'engine_ttft_ms': 34,
#                 'engine_ttlt_ms': 72,
#                 'pre_inference_ms': 117,
#                 'service_tbt_ms': 5,
#                 'service_ttft_ms': 300,
#                 'service_ttlt_ms': 346,
#                 'total_duration_ms': 232,
#                 'user_visible_ttft_ms': 183
#             }
# ...

# %% [markdown]
# ## 3、tool_choice取值为required

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = llm_deepseek.bind_tools([get_weather],tool_choice="required")

response = model_with_tools.invoke("北京今天的天气如何？")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 18,
#             'prompt_tokens': 134,
#             'total_tokens': 152,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 4,
#                 'engine_ttft_ms': 45,
#                 'engine_ttlt_ms': 123,
#                 'pre_inference_ms': 94,
#                 'service_tbt_ms': 5,
#                 'service_ttft_ms': 304,
#                 'service_ttlt_ms': 370,
#                 'total_duration_ms': 301,
#                 'user_visible_ttft_ms': 209
#             }
#         },
# ...

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = llm_deepseek.bind_tools([get_weather],tool_choice="required")

response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 18,
#             'prompt_tokens': 134,
#             'total_tokens': 152,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 5,
#                 'engine_ttft_ms': 44,
#                 'engine_ttlt_ms': 131,
#                 'pre_inference_ms': 86,
#                 'service_tbt_ms': 5,
#                 'service_ttft_ms': 273,
#                 'service_ttlt_ms': 355,
#                 'total_duration_ms': 281,
#                 'user_visible_ttft_ms': 187
#             }
#         },
# ...

# %% [markdown]
# ## 4、强制调用指定的工具

# %%
from langchain.tools import tool
from langchain.messages import HumanMessage


@tool(parse_docstring=True)
def get_weather1(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'

@tool(parse_docstring=True)
def get_weather2(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = llm_deepseek.bind_tools([get_weather1,get_weather2],tool_choice="get_weather2")

response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 19,
#             'prompt_tokens': 160,
#             'total_tokens': 179,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 4,
#                 'engine_ttft_ms': 33,
#                 'engine_ttlt_ms': 110,
#                 'pre_inference_ms': 141,
#                 'service_tbt_ms': 4,
#                 'service_ttft_ms': 331,
#                 'service_ttlt_ms': 402,
#                 'total_duration_ms': 271,
#                 'user_visible_ttft_ms': 190
#             }
#         },
# ...

# %%
from langchain.tools import tool
from langchain.messages import HumanMessage


@tool(parse_docstring=True)
def get_weather1(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'

@tool(parse_docstring=True)
def get_weather2(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = llm_deepseek.bind_tools([get_weather1,get_weather2],tool_choice="get_weather1")

response = model_with_tools.invoke("北京今天的天气如何？")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 19,
#             'prompt_tokens': 160,
#             'total_tokens': 179,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 4,
#                 'engine_ttft_ms': 39,
#                 'engine_ttlt_ms': 110,
#                 'pre_inference_ms': 79,
#                 'service_tbt_ms': 5,
#                 'service_ttft_ms': 298,
#                 'service_ttlt_ms': 388,
#                 'total_duration_ms': 318,
#                 'user_visible_ttft_ms': 220
#             }
#         },
# ...
